# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from pylab import * 
import matplotlib
matplotlib.rcParams['font.family'] = 'Microsoft YaHei'
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']

# %%
data=pd.read_csv('2019opendog.csv')

# %%
import os
print(os.getcwd())
# os.chdir('D:/Anaconda/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/')
# print(os.getcwd())
# Out:
# C:\Users\user

# %%
data.head()
# Out:
#    個股代號            公司簡稱       事件日             TCRI(年/月)  事件強度  大事件類別  \
# 0  1218  泰山              20190101  6(2018/09)               0  M_經營層
# 1  1503  士電              20190101  4(2018/09)               0  M_經營層
# 2  1504  東元              20190101  4(2018/09)               0  M_經營層
# 3  1709  和益              20190101  5(2018/09)               0  M_經營層
# 4  1721  三晃              20190101  7(2018/09)               0  M_經營層
#
#        小事件類別                    事件內容
# 0  MT06_高管異動     發言人林俐婉內部調動，由江巍峰接任。。
# 1  MT06_高管異動  內部稽核主管林志強內部調動，由莊文清接任。。
# 2  MT06_高管異動    會計主管藍俊雄內部調動，由林鴻名接任。。
# 3  MT06_高管異動  內部稽核主管游本詮內部調動，由曾筱茜接任。。
# 4  MT06_高管異動    財務經理洪廷宜內部調動，由王婷渝接任。。

# %%
data.columns
# Out:
# Index(['個股代號', '公司簡稱', '事件日', 'TCRI(年/月)', '事件強度', '大事件類別', '小事件類別', '事件內容'], dtype='object')

# %%
data.dtypes
# Out:
# 個股代號          int64
# 公司簡稱         object
# 事件日           int64
# TCRI(年/月)    object
# 事件強度          int64
# 大事件類別        object
# 小事件類別        object
# 事件內容         object
# dtype: object

# %% [markdown]
# 資料預處理:刪除不需要的資料

# %%
data.isnull().sum()
# Out:
# 個股代號           0
# 公司簡稱         928
# 事件日            0
# TCRI(年/月)      0
# 事件強度           0
# 大事件類別          0
# 小事件類別          0
# 事件內容           0
# dtype: int64

# %%
nullcompany=data[data.iloc[:,1].isnull()==True].iloc[:,0].unique()
nullcompany.sort()
nullcompany
# Out:
# array([  1262,   1566,   1787,   1814,   1819,   2475,   3431,   3452,
#          3519,   3562,   3579,   4135,   4159,   4180,   4193,   4415,
#          4427,   5256,   5259,   5317,   6490,   6553,   6562,   6656,
#          8041,   8127,   8479,   8496,   8913,   9157, 910708, 911619],
#       dtype=int64)

# %% [markdown]
# 股票1262: 綠悅 於2019年10月下市
# 股票1814: 東光訊 於2019年10月下市
# 股票3452: 益通光能 於2020年1月下市
# 股票3562: 頂晶科 於2020年2月下市
# 股票4135: 天賜爾 於2019年10月下市
# 股票4193: 喬本生醫 於2019年10月下市
# 股票4415: 台原藥 於2019年12月下市
# 股票5256: 銳捷 於2020年1月下市
# 股票5259: 益智博國際  於2019年11下市
# 股票6553: 豐華 於2019年12月下市
# 股票6562: 聯亞藥 於2019年11月下市
# 股票8127: 利汎 於2019年10月下市
# 股票8479: 台灣藝術 於2019年10月下市
# 股票8913: 全銓租賃 於2020年1月下市
# 股票9157: 陽光能源 於2019年11月下市

# %%
df=data.dropna(inplace=False)
df.isna().sum()
# Out:
# 個股代號         0
# 公司簡稱         0
# 事件日          0
# TCRI(年/月)    0
# 事件強度         0
# 大事件類別        0
# 小事件類別        0
# 事件內容         0
# dtype: int64

# %%
len(df)
# Out:
# 22775

# %% [markdown]
# 整理並新增欄位

# %%
TCRI=[]
for i in range(0,len(df)):
    TCRI.append(df.iloc[i,3][0])

# %%
df=df.drop(columns=['TCRI(年/月)'])
df.head()
# Out:
#    個股代號            公司簡稱       事件日  事件強度  大事件類別      小事件類別  \
# 0  1218  泰山              20190101     0  M_經營層  MT06_高管異動
# 1  1503  士電              20190101     0  M_經營層  MT06_高管異動
# 2  1504  東元              20190101     0  M_經營層  MT06_高管異動
# 3  1709  和益              20190101     0  M_經營層  MT06_高管異動
# 4  1721  三晃              20190101     0  M_經營層  MT06_高管異動
#
#                      事件內容
# 0     發言人林俐婉內部調動，由江巍峰接任。。
# 1  內部稽核主管林志強內部調動，由莊文清接任。。
# 2    會計主管藍俊雄內部調動，由林鴻名接任。。
# 3  內部稽核主管游本詮內部調動，由曾筱茜接任。。
# 4    財務經理洪廷宜內部調動，由王婷渝接任。。

# %%
df.insert(3, 'TCRI', TCRI)
df
# Out:
#        個股代號            公司簡稱       事件日 TCRI  事件強度   大事件類別  \
# 0      1218  泰山              20190101    6     0   M_經營層
# 1      1503  士電              20190101    4     0   M_經營層
# 2      1504  東元              20190101    4     0   M_經營層
# 3      1709  和益              20190101    5     0   M_經營層
# 4      1721  三晃              20190101    7     0   M_經營層
# 5      1817   凱撒衛            20190101    6     0   M_經營層
# 6      2064  晉椿              20190101    7    -1   M_經營層
# 7      2207   和泰車            20190101    4     0   M_經營層
# 8      2330   台積電            20190101    1    -1   M_經營層
# 9      2357  華碩              20190101    2     0   M_經營層
# 10     2377  微星              20190101    3     0   M_經營層
# 11     2442   新美齊            20190101    7     0   M_經營層
# 12     2724  富驛-KY           20190101    D     0   M_經營層
# 13     2750  桃禧              20190101          0   M_經營層
# 14     2852   第一保            20190101          0   M_經營層
# 15     2888   新光金            20190101          0   M_經營層
# 16     3004   豐達科            20190101    5     0   M_經營層
# 17     3167  大量              20190101    5     0   M_經營層
# 18     4104  佳醫              20190101    5     0   M_經營層
# 19     4138  曜亞              20190101    6     0   M_經營層
# 20     4168  醣聯              20190101    7     0   M_經營層
# 21     4402  福大              20190101    D     0   M_經營層
# 22     4535  至興              20190101    5     0   M_經營層
# 23     4726  永昕              20190101    7    -1   M_經營層
# 24     4945    陞達科技          20190101    6     0   M_經營層
# 25     4987  科誠              20190101    5     0   M_經營層
# 26     6201   亞弘電            20190101    5     0   M_經營層
# 27     6221  晉泰              20190101    6     0   M_經營層
# 28     6251  定穎              20190101    6     0   M_經營層
# 29     6407  相互              20190101    8     0   M_經營層
# ...     ...             ...       ...  ...   ...     ...
# 23673  3653  健策              20191231    4     0  I_產業前景
# 23674  3682   亞太電            20191231    6    -1  I_產業前景
# 23675  4136  太和-KY           20191231    8    -2    R_危機
# 23676  4138  曜亞              20191231    6     0   M_經營層
# 23677  4150   優你康            20191231    8     0  I_產業前景
# 23678  4170  鑫品              20191231    8     1  I_產業前景
# 23679  4540    全球傳動          20191231    6     0   M_經營層
# 23680  4560  強信-KY           20191231    5     0  I_產業前景
# 23681  4806  昇華              20191231          0  I_產業前景
# 23682  4904  遠傳              20191231    2    -1  I_產業前景
# 23683  4908  前鼎              20191231    6    -1  F_市場交易
# 23684  4960   誠美材            20191231    D     0   M_經營層
# 23685  5278  尚凡              20191231    6    -1   M_經營層
# 23686  5347  世界              20191231    2     0  I_產業前景
# 23687  5383  金利              20191231    D     1   M_經營層
# 23688  5607   遠雄港            20191231    6     0  I_產業前景
# 23689  6023   元大期            20191231          1  I_產業前景
# 23690  6024   群益期            20191231         -1   M_經營層
# 23691  6111   大宇資            20191231    7     0   M_經營層
# 23692  6265   方土昶            20191231    6    -1   M_經營層
# 23693  6443  元晶              20191231    8     1  I_產業前景
# 23694  6543    普惠醫工          20191231    6     0   M_經營層
# 23695  6611  方舟              20191231    8    -1  F_市場交易
# 23696  6625  必應              20191231          0  I_產業前景
# 23697  6709  昱厚              20191231    8    -1   M_經營層
# 23698  6715  嘉基              20191231    6     1  I_產業前景
# 23699  6736   碩辣椒            20191231         -1  F_市場交易
# 23700  8028     昇陽半導體        20191231    6     0  I_產業前景
# 23701  8033  雷虎              20191231    8     0  I_產業前景
# 23702  8482  商億-KY           20191231    5     0  I_產業前景
#
#                       小事件類別                                               事件內容
# 0                 MT06_高管異動                                發言人林俐婉內部調動，由江巍峰接任。。
# 1                 MT06_高管異動                             內部稽核主管林志強內部調動，由莊文清接任。。
# 2                 MT06_高管異動                               會計主管藍俊雄內部調動，由林鴻名接任。。
# 3                 MT06_高管異動                             內部稽核主管游本詮內部調動，由曾筱茜接任。。
# 4                 MT06_高管異動                               財務經理洪廷宜內部調動，由王婷渝接任。。
# 5                 MT06_高管異動                               研發主管吳政峰內部調動，由朱清立接任。。
# 6                 MT06_高管異動                   總經理高進義離職，由陳譽接任。。發言人高進義離職，由陳譽接任。。
# 7                 MT02_董監異動          改派1董。董事大野勝仁(豐田自動車代表)卸任。董事長沼一生(豐田自動車代表)新任。
# 8                 MT02_董監異動                               辭任1董。獨立董事湯馬斯?延吉布斯卸任。
# 9                 MT06_高管異動                                總經理沈振來內部調動，由胡書賓接任。。
# 10                MT06_高管異動                                 總經理徐祥內部調動，由江勝昌接任。。
# 11             MO04_經營權轉讓疑慮  新美齊澄清報載提及本公司停業及隱射屬大同集團上市櫃公司之報導。。1.報導內容：大同集團上市櫃...
# 12                MT02_董監異動  改派1董。董事周威良(Furama Hotel International Manageme...
# 13                MT06_高管異動                               會計主管林慧茹內部調動，由楊崑岳接任。。
# 14                MT06_高管異動                               財務經理李易致內部調動，由施冬森接任。。
# 15                MT06_高管異動                               會計主管施貽昶內部調動，由呂雅茹接任。。
# 16                MT06_高管異動                                總經理邱智科內部調動，由林威村接任。。
# 17                MT06_高管異動                               研發主管宋漢釧內部調動，由商國強接任。。
# 18                MT06_高管異動                                 總經理高省內部調動，由張明正接任。。
# 19                MT06_高管異動                                總經理傅若軒內部調動，由吳國龍接任。。
# 20                MT06_高管異動                                總經理張東玄內部調動，由楊玫君接任。。
# 21                MT06_高管異動                               會計主管莊清揚內部調動，由何子龍接任。。
# 22                MT06_高管異動                               研發主管蕭永隆內部調動，由吳榮豐接任。。
# 23                MT06_高管異動  總經理溫國蘭離職(同年12/20提出辭職書, 轉任顧問)，由林榮錦接任。。發言人溫國蘭離職(...
# 24                MT06_高管異動                                總經理李坤蒼內部調動，由鄭淳仁接任。。
# 25                MT06_高管異動                                總經理戴奉義內部調動，由姚啟正接任。。
# 26                MT06_高管異動             總經理許文鼎內部調動，由許瑞峰接任。。發言人許文鼎內部調動，由許瑞峰接任。。
# 27                MT06_高管異動                                總經理林澤鈿內部調動，由黃文宏接任。。
# 28                MT06_高管異動                               會計主管江玲螢內部調動，由倪佩婷接任。。
# 29                MT06_高管異動                                總經理林錦鴻內部調動，由張智明接任。。
# ...                     ...                                                ...
# 23673       IF02_投資/併購/組織策略  健策精密將斥資 3.141 億元，以每股 10.47 元取得金利私募 3 萬張、37.78%...
# 23674     IP01_成本/產能變動或資本支出  5G釋照競標進行第16天，至今已累計160回合，本日結束時暫時得標價合計841.7億元。其中...
# 23675           RB10_輔導券商辭任                   太和-KY公告協辦輔導推薦證券商台新綜合證券股份有限公司辭任。。
# 23676             MT02_董監異動  改派2董。董事游舒帆(佳醫健康事業代表)卸任。董事楊龍和(佳醫健康事業代表)卸任。董事張明正...
# 23677       IF02_投資/併購/組織策略  優你康子公司視霸光學於2019/12/31以總金額台幣26,000仟元，向昱嘉科技(本公司6...
# 23678  IS01_營收變動或客戶/商品/通路策略  鑫品生醫與美國公司MIRROR BIOLOGICS,INC.簽訂獨家經銷協議，雙方協議以投資...
# 23679             MT02_董監異動       改派1董。董事黃福興(中盈投資開發代表)卸任。董事李(女英)娟(中盈投資開發代表)新任。
# 23680     IP01_成本/產能變動或資本支出  強信-KY代孫公司強信機械科技(萊州)公告，為營運擴展需求，向萊州市自然資源和規劃局取得坐落...
# 23681          IF03_財務協議/糾紛  昇華電影投資案債權收回情形及保全措施執行進度：。1.依財團法人中華民國證券櫃檯買賣中心201...
# 23682     IP01_成本/產能變動或資本支出  5G釋照競標進行第16天，至今已累計160回合，本日結束時暫時得標價合計841.7億元。其中...
# 23683          FS02_股價暴跌或異常                     2019/12/31收盤價40.30元，月報酬下跌31%。。
# 23684             MT06_高管異動                       代理總經理羅來煌任期屆滿。總經理則仍為何昭陽，無異動。。
# 23685           MO06_董監持股質押  董事長之法人代表人張家銘2019/12/31設質300,000股給華南商業銀行，累計設質35...
# 23686     IP01_成本/產能變動或資本支出  世界先進評估跨足晶圓薄化領域，搶進晶圓薄化市場機率高。晶圓薄化是晶圓製造後到封裝之間的一個重...
# 23687          MO05_經營權異動換手  健策精密將斥資 3.141 億元，以每股 10.47 元取得金利私募 3 萬張、37.78%...
# 23688     IP01_成本/產能變動或資本支出  遠雄港代子公司遠雄航空自由貿易港區股份有限公司公告為配合營運需要向集團企業東源營造工程股份有...
# 23689       IF01_增資/減資/融資發債  元大期貨股份有限公司申報以現金增資發行普通股17,700,000股，每股面額10元，總額新臺...
# 23690             MT02_董監異動                                    辭任1董。獨立董事許嘉棟卸任。
# 23691             MT06_高管異動                                      研發主管張孝全內部調動。。
# 23692             MT02_董監異動                                     辭任1監。監察人黃怡禎卸任。
# 23693  IS01_營收變動或客戶/商品/通路策略  元晶明年訂單能見度高，除與國際能源開發基金的子公司訂單 180 MW，還有每年穩定貢獻的既有...
# 23694             MT02_董監異動              改派1董。董事林登宗(高大科技代表)卸任。董事陳伯禎(高大科技代表)新任。
# 23695          FS02_股價暴跌或異常                      2019/12/31收盤價6.70元，月報酬下跌39%。。
# 23696        IS02_客戶/商品合約議題  台北 2020 跨年晚會傳出網路轉播權爭議，晚會共同得標者必應，傳出未與華視協議，就將網路轉...
# 23697             MT06_高管異動                                內部稽核主管莊婉如離職(生涯規劃)。。
# 23698  IS01_營收變動或客戶/商品/通路策略  2018年09月累計營收1,496,639千元，年增162%。2018年09月單月營收161...
# 23699          FS02_股價暴跌或異常                     2019/12/31收盤價35.00元，月報酬下跌43%。。
# 23700  IS01_營收變動或客戶/商品/通路策略  世界先進評估跨足晶圓薄化領域，搶進晶圓薄化市場機率高。晶圓薄化是晶圓製造後到封裝之間的一個重...
# 23701          IF03_財務協議/糾紛  1.雷虎科技與香港中澤文化投資股份有限公司仲裁案號(補充公告)：雷虎科技將子公司英屬維京群島...
# 23702       IF02_投資/併購/組織策略  商億-KY公告董事會為配合柬埔寨孫公司發展需求，擬透過子公司Shayne Internati...
#
# [22775 rows x 8 columns]

# %% [markdown]
# 把事件日分類成月份和季

# %%
month=[]
for i in range(0,len(df)):
    month.append(str(df.iloc[i,2])[4:6])

# %%
df.insert(3, 'Month', month)
df
# Out:
#        個股代號            公司簡稱       事件日 Month TCRI  事件強度   大事件類別  \
# 0      1218  泰山              20190101    01    6     0   M_經營層
# 1      1503  士電              20190101    01    4     0   M_經營層
# 2      1504  東元              20190101    01    4     0   M_經營層
# 3      1709  和益              20190101    01    5     0   M_經營層
# 4      1721  三晃              20190101    01    7     0   M_經營層
# 5      1817   凱撒衛            20190101    01    6     0   M_經營層
# 6      2064  晉椿              20190101    01    7    -1   M_經營層
# 7      2207   和泰車            20190101    01    4     0   M_經營層
# 8      2330   台積電            20190101    01    1    -1   M_經營層
# 9      2357  華碩              20190101    01    2     0   M_經營層
# 10     2377  微星              20190101    01    3     0   M_經營層
# 11     2442   新美齊            20190101    01    7     0   M_經營層
# 12     2724  富驛-KY           20190101    01    D     0   M_經營層
# 13     2750  桃禧              20190101    01          0   M_經營層
# 14     2852   第一保            20190101    01          0   M_經營層
# 15     2888   新光金            20190101    01          0   M_經營層
# 16     3004   豐達科            20190101    01    5     0   M_經營層
# 17     3167  大量              20190101    01    5     0   M_經營層
# 18     4104  佳醫              20190101    01    5     0   M_經營層
# 19     4138  曜亞              20190101    01    6     0   M_經營層
# 20     4168  醣聯              20190101    01    7     0   M_經營層
# 21     4402  福大              20190101    01    D     0   M_經營層
# 22     4535  至興              20190101    01    5     0   M_經營層
# 23     4726  永昕              20190101    01    7    -1   M_經營層
# 24     4945    陞達科技          20190101    01    6     0   M_經營層
# 25     4987  科誠              20190101    01    5     0   M_經營層
# 26     6201   亞弘電            20190101    01    5     0   M_經營層
# 27     6221  晉泰              20190101    01    6     0   M_經營層
# 28     6251  定穎              20190101    01    6     0   M_經營層
# 29     6407  相互              20190101    01    8     0   M_經營層
# ...     ...             ...       ...   ...  ...   ...     ...
# 23673  3653  健策              20191231    12    4     0  I_產業前景
# 23674  3682   亞太電            20191231    12    6    -1  I_產業前景
# 23675  4136  太和-KY           20191231    12    8    -2    R_危機
# 23676  4138  曜亞              20191231    12    6     0   M_經營層
# 23677  4150   優你康            20191231    12    8     0  I_產業前景
# 23678  4170  鑫品              20191231    12    8     1  I_產業前景
# 23679  4540    全球傳動          20191231    12    6     0   M_經營層
# 23680  4560  強信-KY           20191231    12    5     0  I_產業前景
# 23681  4806  昇華              20191231    12          0  I_產業前景
# 23682  4904  遠傳              20191231    12    2    -1  I_產業前景
# 23683  4908  前鼎              20191231    12    6    -1  F_市場交易
# 23684  4960   誠美材            20191231    12    D     0   M_經營層
# 23685  5278  尚凡              20191231    12    6    -1   M_經營層
# 23686  5347  世界              20191231    12    2     0  I_產業前景
# 23687  5383  金利              20191231    12    D     1   M_經營層
# 23688  5607   遠雄港            20191231    12    6     0  I_產業前景
# 23689  6023   元大期            20191231    12          1  I_產業前景
# 23690  6024   群益期            20191231    12         -1   M_經營層
# 23691  6111   大宇資            20191231    12    7     0   M_經營層
# 23692  6265   方土昶            20191231    12    6    -1   M_經營層
# 23693  6443  元晶              20191231    12    8     1  I_產業前景
# 23694  6543    普惠醫工          20191231    12    6     0   M_經營層
# 23695  6611  方舟              20191231    12    8    -1  F_市場交易
# 23696  6625  必應              20191231    12          0  I_產業前景
# 23697  6709  昱厚              20191231    12    8    -1   M_經營層
# 23698  6715  嘉基              20191231    12    6     1  I_產業前景
# 23699  6736   碩辣椒            20191231    12         -1  F_市場交易
# 23700  8028     昇陽半導體        20191231    12    6     0  I_產業前景
# 23701  8033  雷虎              20191231    12    8     0  I_產業前景
# 23702  8482  商億-KY           20191231    12    5     0  I_產業前景
#
#                       小事件類別                                               事件內容
# 0                 MT06_高管異動                                發言人林俐婉內部調動，由江巍峰接任。。
# 1                 MT06_高管異動                             內部稽核主管林志強內部調動，由莊文清接任。。
# 2                 MT06_高管異動                               會計主管藍俊雄內部調動，由林鴻名接任。。
# 3                 MT06_高管異動                             內部稽核主管游本詮內部調動，由曾筱茜接任。。
# 4                 MT06_高管異動                               財務經理洪廷宜內部調動，由王婷渝接任。。
# 5                 MT06_高管異動                               研發主管吳政峰內部調動，由朱清立接任。。
# 6                 MT06_高管異動                   總經理高進義離職，由陳譽接任。。發言人高進義離職，由陳譽接任。。
# 7                 MT02_董監異動          改派1董。董事大野勝仁(豐田自動車代表)卸任。董事長沼一生(豐田自動車代表)新任。
# 8                 MT02_董監異動                               辭任1董。獨立董事湯馬斯?延吉布斯卸任。
# 9                 MT06_高管異動                                總經理沈振來內部調動，由胡書賓接任。。
# 10                MT06_高管異動                                 總經理徐祥內部調動，由江勝昌接任。。
# 11             MO04_經營權轉讓疑慮  新美齊澄清報載提及本公司停業及隱射屬大同集團上市櫃公司之報導。。1.報導內容：大同集團上市櫃...
# 12                MT02_董監異動  改派1董。董事周威良(Furama Hotel International Manageme...
# 13                MT06_高管異動                               會計主管林慧茹內部調動，由楊崑岳接任。。
# 14                MT06_高管異動                               財務經理李易致內部調動，由施冬森接任。。
# 15                MT06_高管異動                               會計主管施貽昶內部調動，由呂雅茹接任。。
# 16                MT06_高管異動                                總經理邱智科內部調動，由林威村接任。。
# 17                MT06_高管異動                               研發主管宋漢釧內部調動，由商國強接任。。
# 18                MT06_高管異動                                 總經理高省內部調動，由張明正接任。。
# 19                MT06_高管異動                                總經理傅若軒內部調動，由吳國龍接任。。
# 20                MT06_高管異動                                總經理張東玄內部調動，由楊玫君接任。。
# 21                MT06_高管異動                               會計主管莊清揚內部調動，由何子龍接任。。
# 22                MT06_高管異動                               研發主管蕭永隆內部調動，由吳榮豐接任。。
# 23                MT06_高管異動  總經理溫國蘭離職(同年12/20提出辭職書, 轉任顧問)，由林榮錦接任。。發言人溫國蘭離職(...
# 24                MT06_高管異動                                總經理李坤蒼內部調動，由鄭淳仁接任。。
# 25                MT06_高管異動                                總經理戴奉義內部調動，由姚啟正接任。。
# 26                MT06_高管異動             總經理許文鼎內部調動，由許瑞峰接任。。發言人許文鼎內部調動，由許瑞峰接任。。
# 27                MT06_高管異動                                總經理林澤鈿內部調動，由黃文宏接任。。
# 28                MT06_高管異動                               會計主管江玲螢內部調動，由倪佩婷接任。。
# 29                MT06_高管異動                                總經理林錦鴻內部調動，由張智明接任。。
# ...                     ...                                                ...
# 23673       IF02_投資/併購/組織策略  健策精密將斥資 3.141 億元，以每股 10.47 元取得金利私募 3 萬張、37.78%...
# 23674     IP01_成本/產能變動或資本支出  5G釋照競標進行第16天，至今已累計160回合，本日結束時暫時得標價合計841.7億元。其中...
# 23675           RB10_輔導券商辭任                   太和-KY公告協辦輔導推薦證券商台新綜合證券股份有限公司辭任。。
# 23676             MT02_董監異動  改派2董。董事游舒帆(佳醫健康事業代表)卸任。董事楊龍和(佳醫健康事業代表)卸任。董事張明正...
# 23677       IF02_投資/併購/組織策略  優你康子公司視霸光學於2019/12/31以總金額台幣26,000仟元，向昱嘉科技(本公司6...
# 23678  IS01_營收變動或客戶/商品/通路策略  鑫品生醫與美國公司MIRROR BIOLOGICS,INC.簽訂獨家經銷協議，雙方協議以投資...
# 23679             MT02_董監異動       改派1董。董事黃福興(中盈投資開發代表)卸任。董事李(女英)娟(中盈投資開發代表)新任。
# 23680     IP01_成本/產能變動或資本支出  強信-KY代孫公司強信機械科技(萊州)公告，為營運擴展需求，向萊州市自然資源和規劃局取得坐落...
# 23681          IF03_財務協議/糾紛  昇華電影投資案債權收回情形及保全措施執行進度：。1.依財團法人中華民國證券櫃檯買賣中心201...
# 23682     IP01_成本/產能變動或資本支出  5G釋照競標進行第16天，至今已累計160回合，本日結束時暫時得標價合計841.7億元。其中...
# 23683          FS02_股價暴跌或異常                     2019/12/31收盤價40.30元，月報酬下跌31%。。
# 23684             MT06_高管異動                       代理總經理羅來煌任期屆滿。總經理則仍為何昭陽，無異動。。
# 23685           MO06_董監持股質押  董事長之法人代表人張家銘2019/12/31設質300,000股給華南商業銀行，累計設質35...
# 23686     IP01_成本/產能變動或資本支出  世界先進評估跨足晶圓薄化領域，搶進晶圓薄化市場機率高。晶圓薄化是晶圓製造後到封裝之間的一個重...
# 23687          MO05_經營權異動換手  健策精密將斥資 3.141 億元，以每股 10.47 元取得金利私募 3 萬張、37.78%...
# 23688     IP01_成本/產能變動或資本支出  遠雄港代子公司遠雄航空自由貿易港區股份有限公司公告為配合營運需要向集團企業東源營造工程股份有...
# 23689       IF01_增資/減資/融資發債  元大期貨股份有限公司申報以現金增資發行普通股17,700,000股，每股面額10元，總額新臺...
# 23690             MT02_董監異動                                    辭任1董。獨立董事許嘉棟卸任。
# 23691             MT06_高管異動                                      研發主管張孝全內部調動。。
# 23692             MT02_董監異動                                     辭任1監。監察人黃怡禎卸任。
# 23693  IS01_營收變動或客戶/商品/通路策略  元晶明年訂單能見度高，除與國際能源開發基金的子公司訂單 180 MW，還有每年穩定貢獻的既有...
# 23694             MT02_董監異動              改派1董。董事林登宗(高大科技代表)卸任。董事陳伯禎(高大科技代表)新任。
# 23695          FS02_股價暴跌或異常                      2019/12/31收盤價6.70元，月報酬下跌39%。。
# 23696        IS02_客戶/商品合約議題  台北 2020 跨年晚會傳出網路轉播權爭議，晚會共同得標者必應，傳出未與華視協議，就將網路轉...
# 23697             MT06_高管異動                                內部稽核主管莊婉如離職(生涯規劃)。。
# 23698  IS01_營收變動或客戶/商品/通路策略  2018年09月累計營收1,496,639千元，年增162%。2018年09月單月營收161...
# 23699          FS02_股價暴跌或異常                     2019/12/31收盤價35.00元，月報酬下跌43%。。
# 23700  IS01_營收變動或客戶/商品/通路策略  世界先進評估跨足晶圓薄化領域，搶進晶圓薄化市場機率高。晶圓薄化是晶圓製造後到封裝之間的一個重...
# 23701          IF03_財務協議/糾紛  1.雷虎科技與香港中澤文化投資股份有限公司仲裁案號(補充公告)：雷虎科技將子公司英屬維京群島...
# 23702       IF02_投資/併購/組織策略  商億-KY公告董事會為配合柬埔寨孫公司發展需求，擬透過子公司Shayne Internati...
#
# [22775 rows x 9 columns]

# %%
season=[]
for i in range(0,len(df)):
    if (df.iloc[i,3]=="01" or df.iloc[i,3]=="02" or df.iloc[i,3]=="03"):
        season.append("第一季")
    elif (df.iloc[i,3]=="04" or df.iloc[i,3]=="05" or df.iloc[i,3]=="06"):
        season.append("第二季")
    elif (df.iloc[i,3]=="07" or df.iloc[i,3]=="08" or df.iloc[i,3]=="09"):
        season.append("第三季")
    else:
        season.append("第四季")

# %%
df.insert(4, 'Season', season)
df
# Out:
#        個股代號            公司簡稱       事件日 Month Season TCRI  事件強度   大事件類別  \
# 0      1218  泰山              20190101    01    第一季    6     0   M_經營層
# 1      1503  士電              20190101    01    第一季    4     0   M_經營層
# 2      1504  東元              20190101    01    第一季    4     0   M_經營層
# 3      1709  和益              20190101    01    第一季    5     0   M_經營層
# 4      1721  三晃              20190101    01    第一季    7     0   M_經營層
# 5      1817   凱撒衛            20190101    01    第一季    6     0   M_經營層
# 6      2064  晉椿              20190101    01    第一季    7    -1   M_經營層
# 7      2207   和泰車            20190101    01    第一季    4     0   M_經營層
# 8      2330   台積電            20190101    01    第一季    1    -1   M_經營層
# 9      2357  華碩              20190101    01    第一季    2     0   M_經營層
# 10     2377  微星              20190101    01    第一季    3     0   M_經營層
# 11     2442   新美齊            20190101    01    第一季    7     0   M_經營層
# 12     2724  富驛-KY           20190101    01    第一季    D     0   M_經營層
# 13     2750  桃禧              20190101    01    第一季          0   M_經營層
# 14     2852   第一保            20190101    01    第一季          0   M_經營層
# 15     2888   新光金            20190101    01    第一季          0   M_經營層
# 16     3004   豐達科            20190101    01    第一季    5     0   M_經營層
# 17     3167  大量              20190101    01    第一季    5     0   M_經營層
# 18     4104  佳醫              20190101    01    第一季    5     0   M_經營層
# 19     4138  曜亞              20190101    01    第一季    6     0   M_經營層
# 20     4168  醣聯              20190101    01    第一季    7     0   M_經營層
# 21     4402  福大              20190101    01    第一季    D     0   M_經營層
# 22     4535  至興              20190101    01    第一季    5     0   M_經營層
# 23     4726  永昕              20190101    01    第一季    7    -1   M_經營層
# 24     4945    陞達科技          20190101    01    第一季    6     0   M_經營層
# 25     4987  科誠              20190101    01    第一季    5     0   M_經營層
# 26     6201   亞弘電            20190101    01    第一季    5     0   M_經營層
# 27     6221  晉泰              20190101    01    第一季    6     0   M_經營層
# 28     6251  定穎              20190101    01    第一季    6     0   M_經營層
# 29     6407  相互              20190101    01    第一季    8     0   M_經營層
# ...     ...             ...       ...   ...    ...  ...   ...     ...
# 23673  3653  健策              20191231    12    第四季    4     0  I_產業前景
# 23674  3682   亞太電            20191231    12    第四季    6    -1  I_產業前景
# 23675  4136  太和-KY           20191231    12    第四季    8    -2    R_危機
# 23676  4138  曜亞              20191231    12    第四季    6     0   M_經營層
# 23677  4150   優你康            20191231    12    第四季    8     0  I_產業前景
# 23678  4170  鑫品              20191231    12    第四季    8     1  I_產業前景
# 23679  4540    全球傳動          20191231    12    第四季    6     0   M_經營層
# 23680  4560  強信-KY           20191231    12    第四季    5     0  I_產業前景
# 23681  4806  昇華              20191231    12    第四季          0  I_產業前景
# 23682  4904  遠傳              20191231    12    第四季    2    -1  I_產業前景
# 23683  4908  前鼎              20191231    12    第四季    6    -1  F_市場交易
# 23684  4960   誠美材            20191231    12    第四季    D     0   M_經營層
# 23685  5278  尚凡              20191231    12    第四季    6    -1   M_經營層
# 23686  5347  世界              20191231    12    第四季    2     0  I_產業前景
# 23687  5383  金利              20191231    12    第四季    D     1   M_經營層
# 23688  5607   遠雄港            20191231    12    第四季    6     0  I_產業前景
# 23689  6023   元大期            20191231    12    第四季          1  I_產業前景
# 23690  6024   群益期            20191231    12    第四季         -1   M_經營層
# 23691  6111   大宇資            20191231    12    第四季    7     0   M_經營層
# 23692  6265   方土昶            20191231    12    第四季    6    -1   M_經營層
# 23693  6443  元晶              20191231    12    第四季    8     1  I_產業前景
# 23694  6543    普惠醫工          20191231    12    第四季    6     0   M_經營層
# 23695  6611  方舟              20191231    12    第四季    8    -1  F_市場交易
# 23696  6625  必應              20191231    12    第四季          0  I_產業前景
# 23697  6709  昱厚              20191231    12    第四季    8    -1   M_經營層
# 23698  6715  嘉基              20191231    12    第四季    6     1  I_產業前景
# 23699  6736   碩辣椒            20191231    12    第四季         -1  F_市場交易
# 23700  8028     昇陽半導體        20191231    12    第四季    6     0  I_產業前景
# 23701  8033  雷虎              20191231    12    第四季    8     0  I_產業前景
# 23702  8482  商億-KY           20191231    12    第四季    5     0  I_產業前景
#
#                       小事件類別                                               事件內容
# 0                 MT06_高管異動                                發言人林俐婉內部調動，由江巍峰接任。。
# 1                 MT06_高管異動                             內部稽核主管林志強內部調動，由莊文清接任。。
# 2                 MT06_高管異動                               會計主管藍俊雄內部調動，由林鴻名接任。。
# 3                 MT06_高管異動                             內部稽核主管游本詮內部調動，由曾筱茜接任。。
# 4                 MT06_高管異動                               財務經理洪廷宜內部調動，由王婷渝接任。。
# 5                 MT06_高管異動                               研發主管吳政峰內部調動，由朱清立接任。。
# 6                 MT06_高管異動                   總經理高進義離職，由陳譽接任。。發言人高進義離職，由陳譽接任。。
# 7                 MT02_董監異動          改派1董。董事大野勝仁(豐田自動車代表)卸任。董事長沼一生(豐田自動車代表)新任。
# 8                 MT02_董監異動                               辭任1董。獨立董事湯馬斯?延吉布斯卸任。
# 9                 MT06_高管異動                                總經理沈振來內部調動，由胡書賓接任。。
# 10                MT06_高管異動                                 總經理徐祥內部調動，由江勝昌接任。。
# 11             MO04_經營權轉讓疑慮  新美齊澄清報載提及本公司停業及隱射屬大同集團上市櫃公司之報導。。1.報導內容：大同集團上市櫃...
# 12                MT02_董監異動  改派1董。董事周威良(Furama Hotel International Manageme...
# 13                MT06_高管異動                               會計主管林慧茹內部調動，由楊崑岳接任。。
# 14                MT06_高管異動                               財務經理李易致內部調動，由施冬森接任。。
# 15                MT06_高管異動                               會計主管施貽昶內部調動，由呂雅茹接任。。
# 16                MT06_高管異動                                總經理邱智科內部調動，由林威村接任。。
# 17                MT06_高管異動                               研發主管宋漢釧內部調動，由商國強接任。。
# 18                MT06_高管異動                                 總經理高省內部調動，由張明正接任。。
# 19                MT06_高管異動                                總經理傅若軒內部調動，由吳國龍接任。。
# 20                MT06_高管異動                                總經理張東玄內部調動，由楊玫君接任。。
# 21                MT06_高管異動                               會計主管莊清揚內部調動，由何子龍接任。。
# 22                MT06_高管異動                               研發主管蕭永隆內部調動，由吳榮豐接任。。
# 23                MT06_高管異動  總經理溫國蘭離職(同年12/20提出辭職書, 轉任顧問)，由林榮錦接任。。發言人溫國蘭離職(...
# 24                MT06_高管異動                                總經理李坤蒼內部調動，由鄭淳仁接任。。
# 25                MT06_高管異動                                總經理戴奉義內部調動，由姚啟正接任。。
# 26                MT06_高管異動             總經理許文鼎內部調動，由許瑞峰接任。。發言人許文鼎內部調動，由許瑞峰接任。。
# 27                MT06_高管異動                                總經理林澤鈿內部調動，由黃文宏接任。。
# 28                MT06_高管異動                               會計主管江玲螢內部調動，由倪佩婷接任。。
# 29                MT06_高管異動                                總經理林錦鴻內部調動，由張智明接任。。
# ...                     ...                                                ...
# 23673       IF02_投資/併購/組織策略  健策精密將斥資 3.141 億元，以每股 10.47 元取得金利私募 3 萬張、37.78%...
# 23674     IP01_成本/產能變動或資本支出  5G釋照競標進行第16天，至今已累計160回合，本日結束時暫時得標價合計841.7億元。其中...
# 23675           RB10_輔導券商辭任                   太和-KY公告協辦輔導推薦證券商台新綜合證券股份有限公司辭任。。
# 23676             MT02_董監異動  改派2董。董事游舒帆(佳醫健康事業代表)卸任。董事楊龍和(佳醫健康事業代表)卸任。董事張明正...
# 23677       IF02_投資/併購/組織策略  優你康子公司視霸光學於2019/12/31以總金額台幣26,000仟元，向昱嘉科技(本公司6...
# 23678  IS01_營收變動或客戶/商品/通路策略  鑫品生醫與美國公司MIRROR BIOLOGICS,INC.簽訂獨家經銷協議，雙方協議以投資...
# 23679             MT02_董監異動       改派1董。董事黃福興(中盈投資開發代表)卸任。董事李(女英)娟(中盈投資開發代表)新任。
# 23680     IP01_成本/產能變動或資本支出  強信-KY代孫公司強信機械科技(萊州)公告，為營運擴展需求，向萊州市自然資源和規劃局取得坐落...
# 23681          IF03_財務協議/糾紛  昇華電影投資案債權收回情形及保全措施執行進度：。1.依財團法人中華民國證券櫃檯買賣中心201...
# 23682     IP01_成本/產能變動或資本支出  5G釋照競標進行第16天，至今已累計160回合，本日結束時暫時得標價合計841.7億元。其中...
# 23683          FS02_股價暴跌或異常                     2019/12/31收盤價40.30元，月報酬下跌31%。。
# 23684             MT06_高管異動                       代理總經理羅來煌任期屆滿。總經理則仍為何昭陽，無異動。。
# 23685           MO06_董監持股質押  董事長之法人代表人張家銘2019/12/31設質300,000股給華南商業銀行，累計設質35...
# 23686     IP01_成本/產能變動或資本支出  世界先進評估跨足晶圓薄化領域，搶進晶圓薄化市場機率高。晶圓薄化是晶圓製造後到封裝之間的一個重...
# 23687          MO05_經營權異動換手  健策精密將斥資 3.141 億元，以每股 10.47 元取得金利私募 3 萬張、37.78%...
# 23688     IP01_成本/產能變動或資本支出  遠雄港代子公司遠雄航空自由貿易港區股份有限公司公告為配合營運需要向集團企業東源營造工程股份有...
# 23689       IF01_增資/減資/融資發債  元大期貨股份有限公司申報以現金增資發行普通股17,700,000股，每股面額10元，總額新臺...
# 23690             MT02_董監異動                                    辭任1董。獨立董事許嘉棟卸任。
# 23691             MT06_高管異動                                      研發主管張孝全內部調動。。
# 23692             MT02_董監異動                                     辭任1監。監察人黃怡禎卸任。
# 23693  IS01_營收變動或客戶/商品/通路策略  元晶明年訂單能見度高，除與國際能源開發基金的子公司訂單 180 MW，還有每年穩定貢獻的既有...
# 23694             MT02_董監異動              改派1董。董事林登宗(高大科技代表)卸任。董事陳伯禎(高大科技代表)新任。
# 23695          FS02_股價暴跌或異常                      2019/12/31收盤價6.70元，月報酬下跌39%。。
# 23696        IS02_客戶/商品合約議題  台北 2020 跨年晚會傳出網路轉播權爭議，晚會共同得標者必應，傳出未與華視協議，就將網路轉...
# 23697             MT06_高管異動                                內部稽核主管莊婉如離職(生涯規劃)。。
# 23698  IS01_營收變動或客戶/商品/通路策略  2018年09月累計營收1,496,639千元，年增162%。2018年09月單月營收161...
# 23699          FS02_股價暴跌或異常                     2019/12/31收盤價35.00元，月報酬下跌43%。。
# 23700  IS01_營收變動或客戶/商品/通路策略  世界先進評估跨足晶圓薄化領域，搶進晶圓薄化市場機率高。晶圓薄化是晶圓製造後到封裝之間的一個重...
# 23701          IF03_財務協議/糾紛  1.雷虎科技與香港中澤文化投資股份有限公司仲裁案號(補充公告)：雷虎科技將子公司英屬維京群島...
# 23702       IF02_投資/併購/組織策略  商億-KY公告董事會為配合柬埔寨孫公司發展需求，擬透過子公司Shayne Internati...
#
# [22775 rows x 10 columns]

# %% [markdown]
# 事件強度分正的一群，負的一群

# %%
strong=[]
for i in range(0,len(df)):
    if df.iloc[i,6]>0:
        strong.append('positive')
    else:
        strong.append('negative')

# %%
df.insert(7, '強度分類', strong)
df
# Out:
#        個股代號            公司簡稱       事件日 Month Season TCRI  事件強度      強度分類  \
# 0      1218  泰山              20190101    01    第一季    6     0  negative
# 1      1503  士電              20190101    01    第一季    4     0  negative
# 2      1504  東元              20190101    01    第一季    4     0  negative
# 3      1709  和益              20190101    01    第一季    5     0  negative
# 4      1721  三晃              20190101    01    第一季    7     0  negative
# 5      1817   凱撒衛            20190101    01    第一季    6     0  negative
# 6      2064  晉椿              20190101    01    第一季    7    -1  negative
# 7      2207   和泰車            20190101    01    第一季    4     0  negative
# 8      2330   台積電            20190101    01    第一季    1    -1  negative
# 9      2357  華碩              20190101    01    第一季    2     0  negative
# 10     2377  微星              20190101    01    第一季    3     0  negative
# 11     2442   新美齊            20190101    01    第一季    7     0  negative
# 12     2724  富驛-KY           20190101    01    第一季    D     0  negative
# 13     2750  桃禧              20190101    01    第一季          0  negative
# 14     2852   第一保            20190101    01    第一季          0  negative
# 15     2888   新光金            20190101    01    第一季          0  negative
# 16     3004   豐達科            20190101    01    第一季    5     0  negative
# 17     3167  大量              20190101    01    第一季    5     0  negative
# 18     4104  佳醫              20190101    01    第一季    5     0  negative
# 19     4138  曜亞              20190101    01    第一季    6     0  negative
# 20     4168  醣聯              20190101    01    第一季    7     0  negative
# 21     4402  福大              20190101    01    第一季    D     0  negative
# 22     4535  至興              20190101    01    第一季    5     0  negative
# 23     4726  永昕              20190101    01    第一季    7    -1  negative
# 24     4945    陞達科技          20190101    01    第一季    6     0  negative
# 25     4987  科誠              20190101    01    第一季    5     0  negative
# 26     6201   亞弘電            20190101    01    第一季    5     0  negative
# 27     6221  晉泰              20190101    01    第一季    6     0  negative
# 28     6251  定穎              20190101    01    第一季    6     0  negative
# 29     6407  相互              20190101    01    第一季    8     0  negative
# ...     ...             ...       ...   ...    ...  ...   ...       ...
# 23673  3653  健策              20191231    12    第四季    4     0  negative
# 23674  3682   亞太電            20191231    12    第四季    6    -1  negative
# 23675  4136  太和-KY           20191231    12    第四季    8    -2  negative
# 23676  4138  曜亞              20191231    12    第四季    6     0  negative
# 23677  4150   優你康            20191231    12    第四季    8     0  negative
# 23678  4170  鑫品              20191231    12    第四季    8     1  positive
# 23679  4540    全球傳動          20191231    12    第四季    6     0  negative
# 23680  4560  強信-KY           20191231    12    第四季    5     0  negative
# 23681  4806  昇華              20191231    12    第四季          0  negative
# 23682  4904  遠傳              20191231    12    第四季    2    -1  negative
# 23683  4908  前鼎              20191231    12    第四季    6    -1  negative
# 23684  4960   誠美材            20191231    12    第四季    D     0  negative
# 23685  5278  尚凡              20191231    12    第四季    6    -1  negative
# 23686  5347  世界              20191231    12    第四季    2     0  negative
# 23687  5383  金利              20191231    12    第四季    D     1  positive
# 23688  5607   遠雄港            20191231    12    第四季    6     0  negative
# 23689  6023   元大期            20191231    12    第四季          1  positive
# 23690  6024   群益期            20191231    12    第四季         -1  negative
# 23691  6111   大宇資            20191231    12    第四季    7     0  negative
# 23692  6265   方土昶            20191231    12    第四季    6    -1  negative
# 23693  6443  元晶              20191231    12    第四季    8     1  positive
# 23694  6543    普惠醫工          20191231    12    第四季    6     0  negative
# 23695  6611  方舟              20191231    12    第四季    8    -1  negative
# 23696  6625  必應              20191231    12    第四季          0  negative
# 23697  6709  昱厚              20191231    12    第四季    8    -1  negative
# 23698  6715  嘉基              20191231    12    第四季    6     1  positive
# 23699  6736   碩辣椒            20191231    12    第四季         -1  negative
# 23700  8028     昇陽半導體        20191231    12    第四季    6     0  negative
# 23701  8033  雷虎              20191231    12    第四季    8     0  negative
# 23702  8482  商億-KY           20191231    12    第四季    5     0  negative
#
#         大事件類別                 小事件類別  \
# 0       M_經營層             MT06_高管異動
# 1       M_經營層             MT06_高管異動
# 2       M_經營層             MT06_高管異動
# 3       M_經營層             MT06_高管異動
# 4       M_經營層             MT06_高管異動
# 5       M_經營層             MT06_高管異動
# 6       M_經營層             MT06_高管異動
# 7       M_經營層             MT02_董監異動
# 8       M_經營層             MT02_董監異動
# 9       M_經營層             MT06_高管異動
# 10      M_經營層             MT06_高管異動
# 11      M_經營層          MO04_經營權轉讓疑慮
# 12      M_經營層             MT02_董監異動
# 13      M_經營層             MT06_高管異動
# 14      M_經營層             MT06_高管異動
# 15      M_經營層             MT06_高管異動
# 16      M_經營層             MT06_高管異動
# 17      M_經營層             MT06_高管異動
# 18      M_經營層             MT06_高管異動
# 19      M_經營層             MT06_高管異動
# 20      M_經營層             MT06_高管異動
# 21      M_經營層             MT06_高管異動
# 22      M_經營層             MT06_高管異動
# 23      M_經營層             MT06_高管異動
# 24      M_經營層             MT06_高管異動
# 25      M_經營層             MT06_高管異動
# 26      M_經營層             MT06_高管異動
# 27      M_經營層             MT06_高管異動
# 28      M_經營層             MT06_高管異動
# 29      M_經營層             MT06_高管異動
# ...       ...                   ...
# 23673  I_產業前景       IF02_投資/併購/組織策略
# 23674  I_產業前景     IP01_成本/產能變動或資本支出
# 23675    R_危機           RB10_輔導券商辭任
# 23676   M_經營層             MT02_董監異動
# 23677  I_產業前景       IF02_投資/併購/組織策略
# 23678  I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 23679   M_經營層             MT02_董監異動
# 23680  I_產業前景     IP01_成本/產能變動或資本支出
# 23681  I_產業前景          IF03_財務協議/糾紛
# 23682  I_產業前景     IP01_成本/產能變動或資本支出
# 23683  F_市場交易          FS02_股價暴跌或異常
# 23684   M_經營層             MT06_高管異動
# 23685   M_經營層           MO06_董監持股質押
# 23686  I_產業前景     IP01_成本/產能變動或資本支出
# 23687   M_經營層          MO05_經營權異動換手
# 23688  I_產業前景     IP01_成本/產能變動或資本支出
# 23689  I_產業前景       IF01_增資/減資/融資發債
# 23690   M_經營層             MT02_董監異動
# 23691   M_經營層             MT06_高管異動
# 23692   M_經營層             MT02_董監異動
# 23693  I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 23694   M_經營層             MT02_董監異動
# 23695  F_市場交易          FS02_股價暴跌或異常
# 23696  I_產業前景        IS02_客戶/商品合約議題
# 23697   M_經營層             MT06_高管異動
# 23698  I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 23699  F_市場交易          FS02_股價暴跌或異常
# 23700  I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 23701  I_產業前景          IF03_財務協議/糾紛
# 23702  I_產業前景       IF02_投資/併購/組織策略
#
#                                                     事件內容
# 0                                    發言人林俐婉內部調動，由江巍峰接任。。
# 1                                 內部稽核主管林志強內部調動，由莊文清接任。。
# 2                                   會計主管藍俊雄內部調動，由林鴻名接任。。
# 3                                 內部稽核主管游本詮內部調動，由曾筱茜接任。。
# 4                                   財務經理洪廷宜內部調動，由王婷渝接任。。
# 5                                   研發主管吳政峰內部調動，由朱清立接任。。
# 6                       總經理高進義離職，由陳譽接任。。發言人高進義離職，由陳譽接任。。
# 7              改派1董。董事大野勝仁(豐田自動車代表)卸任。董事長沼一生(豐田自動車代表)新任。
# 8                                   辭任1董。獨立董事湯馬斯?延吉布斯卸任。
# 9                                    總經理沈振來內部調動，由胡書賓接任。。
# 10                                    總經理徐祥內部調動，由江勝昌接任。。
# 11     新美齊澄清報載提及本公司停業及隱射屬大同集團上市櫃公司之報導。。1.報導內容：大同集團上市櫃...
# 12     改派1董。董事周威良(Furama Hotel International Manageme...
# 13                                  會計主管林慧茹內部調動，由楊崑岳接任。。
# 14                                  財務經理李易致內部調動，由施冬森接任。。
# 15                                  會計主管施貽昶內部調動，由呂雅茹接任。。
# 16                                   總經理邱智科內部調動，由林威村接任。。
# 17                                  研發主管宋漢釧內部調動，由商國強接任。。
# 18                                    總經理高省內部調動，由張明正接任。。
# 19                                   總經理傅若軒內部調動，由吳國龍接任。。
# 20                                   總經理張東玄內部調動，由楊玫君接任。。
# 21                                  會計主管莊清揚內部調動，由何子龍接任。。
# 22                                  研發主管蕭永隆內部調動，由吳榮豐接任。。
# 23     總經理溫國蘭離職(同年12/20提出辭職書, 轉任顧問)，由林榮錦接任。。發言人溫國蘭離職(...
# 24                                   總經理李坤蒼內部調動，由鄭淳仁接任。。
# 25                                   總經理戴奉義內部調動，由姚啟正接任。。
# 26                總經理許文鼎內部調動，由許瑞峰接任。。發言人許文鼎內部調動，由許瑞峰接任。。
# 27                                   總經理林澤鈿內部調動，由黃文宏接任。。
# 28                                  會計主管江玲螢內部調動，由倪佩婷接任。。
# 29                                   總經理林錦鴻內部調動，由張智明接任。。
# ...                                                  ...
# 23673  健策精密將斥資 3.141 億元，以每股 10.47 元取得金利私募 3 萬張、37.78%...
# 23674  5G釋照競標進行第16天，至今已累計160回合，本日結束時暫時得標價合計841.7億元。其中...
# 23675                   太和-KY公告協辦輔導推薦證券商台新綜合證券股份有限公司辭任。。
# 23676  改派2董。董事游舒帆(佳醫健康事業代表)卸任。董事楊龍和(佳醫健康事業代表)卸任。董事張明正...
# 23677  優你康子公司視霸光學於2019/12/31以總金額台幣26,000仟元，向昱嘉科技(本公司6...
# 23678  鑫品生醫與美國公司MIRROR BIOLOGICS,INC.簽訂獨家經銷協議，雙方協議以投資...
# 23679       改派1董。董事黃福興(中盈投資開發代表)卸任。董事李(女英)娟(中盈投資開發代表)新任。
# 23680  強信-KY代孫公司強信機械科技(萊州)公告，為營運擴展需求，向萊州市自然資源和規劃局取得坐落...
# 23681  昇華電影投資案債權收回情形及保全措施執行進度：。1.依財團法人中華民國證券櫃檯買賣中心201...
# 23682  5G釋照競標進行第16天，至今已累計160回合，本日結束時暫時得標價合計841.7億元。其中...
# 23683                     2019/12/31收盤價40.30元，月報酬下跌31%。。
# 23684                       代理總經理羅來煌任期屆滿。總經理則仍為何昭陽，無異動。。
# 23685  董事長之法人代表人張家銘2019/12/31設質300,000股給華南商業銀行，累計設質35...
# 23686  世界先進評估跨足晶圓薄化領域，搶進晶圓薄化市場機率高。晶圓薄化是晶圓製造後到封裝之間的一個重...
# 23687  健策精密將斥資 3.141 億元，以每股 10.47 元取得金利私募 3 萬張、37.78%...
# 23688  遠雄港代子公司遠雄航空自由貿易港區股份有限公司公告為配合營運需要向集團企業東源營造工程股份有...
# 23689  元大期貨股份有限公司申報以現金增資發行普通股17,700,000股，每股面額10元，總額新臺...
# 23690                                    辭任1董。獨立董事許嘉棟卸任。
# 23691                                      研發主管張孝全內部調動。。
# 23692                                     辭任1監。監察人黃怡禎卸任。
# 23693  元晶明年訂單能見度高，除與國際能源開發基金的子公司訂單 180 MW，還有每年穩定貢獻的既有...
# 23694              改派1董。董事林登宗(高大科技代表)卸任。董事陳伯禎(高大科技代表)新任。
# 23695                      2019/12/31收盤價6.70元，月報酬下跌39%。。
# 23696  台北 2020 跨年晚會傳出網路轉播權爭議，晚會共同得標者必應，傳出未與華視協議，就將網路轉...
# 23697                                內部稽核主管莊婉如離職(生涯規劃)。。
# 23698  2018年09月累計營收1,496,639千元，年增162%。2018年09月單月營收161...
# 23699                     2019/12/31收盤價35.00元，月報酬下跌43%。。
# 23700  世界先進評估跨足晶圓薄化領域，搶進晶圓薄化市場機率高。晶圓薄化是晶圓製造後到封裝之間的一個重...
# 23701  1.雷虎科技與香港中澤文化投資股份有限公司仲裁案號(補充公告)：雷虎科技將子公司英屬維京群島...
# 23702  商億-KY公告董事會為配合柬埔寨孫公司發展需求，擬透過子公司Shayne Internati...
#
# [22775 rows x 11 columns]

# %% [markdown]
# 各欄位的EDA

# %% [markdown]
# 事件強度

# %%
plt.title("事件強度_數量統計長條圖")
plt.xlabel("事件強度")
plt.ylabel("數量")
df.iloc[:,6].value_counts().plot.bar()

# %%
df.groupby('強度分類')['事件強度'].value_counts().unstack().plot.bar(stacked=True)
plt.title("事件強度分類_堆疊長條圖")
plt.xlabel("強度類別")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
positive=df[df.強度分類=="positive"]
negative=df[df.強度分類=="negative"]

# %%
plt.title("事件強度(正)_數量統計長條圖")
plt.xlabel("事件強度(正)")
plt.ylabel("件數")
positive.iloc[:,6].value_counts().plot.bar()

# %%
plt.title("事件強度(負)_數量統計長條圖")
plt.xlabel("事件強度(負)")
plt.ylabel("件數")
negative.iloc[:,6].value_counts().plot.bar()

# %%
df.groupby('Month')['強度分類'].value_counts().unstack().plot.bar(stacked=True)
plt.title("每月事件強度分類_堆疊長條圖")
plt.xlabel("月份")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
positive.groupby('Month')['事件強度'].value_counts().unstack().plot.bar(stacked=True)
plt.title("每月事件強度分類(正)_堆疊長條圖")
plt.xlabel("月份")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
df.groupby('Season')['強度分類'].value_counts().unstack().plot.bar(stacked=True)
plt.title("每季事件強度分類_堆疊長條圖")
plt.xlabel("每季")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
positive.groupby('Season')['事件強度'].value_counts().unstack().plot.bar(stacked=True)
plt.title("每季事件強度分類(正)_堆疊長條圖")
plt.xlabel("每季")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %% [markdown]
# 個股代號=公司簡稱，所以只做公司簡稱統計圖

# %%
df.公司簡稱.describe()
# Out:
# count             22775
# unique             1959
# top       台積電
# freq                164
# Name: 公司簡稱, dtype: object

# %%
df.iloc[:,1].value_counts()
# Out:
# 台積電               164
# 大同                126
# 鴻海                105
# 誠美材                81
# 大飲                 73
# 鈞泰                 72
# 昇華                 71
# 中鋼                 68
# 新零售                67
# 中華電                66
# 亞獅康-KY             65
# 長榮航                64
# 天剛                 63
# 永利聯合               61
# 日月光投控              53
# 松崗                 50
# 氣立                 50
# 德宏                 49
# 達能                 45
# 天蔥                 45
# 雙美                 44
# 台灣大                44
# 美時                 43
# 台塑                 42
# 燦星旅                42
# 大略-KY              41
# 富邦金                41
# 中信金                41
# 國泰金                40
# 華航                 40
#                  ...
# 康師傅-DR              1
# 通嘉                  1
# 聖馬丁-DR              1
# 良得電                 1
# 冠亞                  1
# 安心                  1
# 亞力                  1
# 中菲                  1
# 茂順                  1
# 第一店                 1
# 天仁                  1
# 連鋐科技                1
# 宜新實業                1
# 大甲                  1
# 佑華                  1
# 創源                  1
# 地球                  1
# 青鋼                  1
# 育富                  1
# 台燿                  1
# 超豐                  1
# 群翊                  1
# 運錩                  1
# 勁豐                  1
# 立誠                  1
# 雙邦                  1
# 廣宇                  1
# 松翰                  1
# 歐格                  1
# 志豐                  1
# Name: 公司簡稱, Length: 1959, dtype: int64

# %%
TSMC=df[df.公司簡稱=='台積電          ']

# %%
TSMC
# Out:
#        個股代號           公司簡稱       事件日 Month Season TCRI  事件強度      強度分類  \
# 8      2330  台積電            20190101    01    第一季    1    -1  negative
# 825    2330  台積電            20190115    01    第一季    1     1  positive
# 927    2330  台積電            20190118    01    第一季    1     0  negative
# 1122   2330  台積電            20190128    01    第一季    1    -1  negative
# 1167   2330  台積電            20190129    01    第一季    1    -1  negative
# 1299   2330  台積電            20190201    02    第一季    1     0  negative
# 1357   2330  台積電            20190211    02    第一季    1     0  negative
# 1426   2330  台積電            20190212    02    第一季    1    -1  negative
# 1995   2330  台積電            20190221    02    第一季    1     0  negative
# 2080   2330  台積電            20190225    02    第一季    1     1  positive
# 2110   2330  台積電            20190226    02    第一季    1     0  negative
# 2366   2330  台積電            20190306    03    第一季    1     0  negative
# 2432   2330  台積電            20190307    03    第一季    1     0  negative
# 2582   2330  台積電            20190308    03    第一季    1     0  negative
# 3012   2330  台積電            20190312    03    第一季    1     0  negative
# 3062   2330  台積電            20190313    03    第一季    1     0  negative
# 3167   2330  台積電            20190315    03    第一季    1     0  negative
# 3329   2330  台積電            20190319    03    第一季    1     0  negative
# 3449   2330  台積電            20190321    03    第一季    1     0  negative
# 3538   2330  台積電            20190322    03    第一季    1    -1  negative
# 3643   2330  台積電            20190325    03    第一季    1     0  negative
# 3733   2330  台積電            20190326    03    第一季    1     0  negative
# 3802   2330  台積電            20190327    03    第一季    1     0  negative
# 4154   2330  台積電            20190402    04    第二季    1     0  negative
# 4214   2330  台積電            20190403    04    第二季    1     0  negative
# 4633   2330  台積電            20190410    04    第二季    1    -1  negative
# 5046   2330  台積電            20190415    04    第二季    1     0  negative
# 5172   2330  台積電            20190417    04    第二季    1     0  negative
# 5173   2330  台積電            20190417    04    第二季    1     0  negative
# 5174   2330  台積電            20190417    04    第二季    1     0  negative
# ...     ...            ...       ...   ...    ...  ...   ...       ...
# 17158  2330  台積電            20191007    10    第四季    1     0  negative
# 17328  2330  台積電            20191008    10    第四季    1     0  negative
# 17329  2330  台積電            20191008    10    第四季    1     0  negative
# 18062  2330  台積電            20191014    10    第四季    1     0  negative
# 18233  2330  台積電            20191016    10    第四季    1     0  negative
# 18290  2330  台積電            20191017    10    第四季    1     1  positive
# 18409  2330  台積電            20191021    10    第四季    1     0  negative
# 18469  2330  台積電            20191022    10    第四季    1     0  negative
# 18535  2330  台積電            20191023    10    第四季    1     0  negative
# 18536  2330  台積電            20191023    10    第四季    1     0  negative
# 18633  2330  台積電            20191025    10    第四季    1     0  negative
# 18692  2330  台積電            20191028    10    第四季    1     0  negative
# 18741  2330  台積電            20191029    10    第四季    1     0  negative
# 18742  2330  台積電            20191029    10    第四季    1     1  positive
# 18809  2330  台積電            20191030    10    第四季    1     0  negative
# 18863  2330  台積電            20191031    10    第四季    1     0  negative
# 18932  2330  台積電            20191101    11    第四季    1     1  positive
# 19017  2330  台積電            20191104    11    第四季    1     0  negative
# 19087  2330  台積電            20191105    11    第四季    1     0  negative
# 19188  2330  台積電            20191106    11    第四季    1     0  negative
# 19592  2330  台積電            20191108    11    第四季    1     0  negative
# 19593  2330  台積電            20191108    11    第四季    1     1  positive
# 20158  2330  台積電            20191111    11    第四季    1     0  negative
# 20334  2330  台積電            20191112    11    第四季    1     0  negative
# 20436  2330  台積電            20191113    11    第四季    1     0  negative
# 21506  2330  台積電            20191205    12    第四季    1     1  positive
# 21781  2330  台積電            20191208    12    第四季    1     1  positive
# 22588  2330  台積電            20191211    12    第四季    1     0  negative
# 23299  2330  台積電            20191224    12    第四季    1     1  positive
# 23596  2330  台積電            20191230    12    第四季    1     1  positive
#
#            大事件類別                 小事件類別  \
# 8          M_經營層             MT02_董監異動
# 825       I_產業前景     IP01_成本/產能變動或資本支出
# 927       I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 1122      I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 1167      I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 1299      I_產業前景     IP01_成本/產能變動或資本支出
# 1357      I_產業前景     IP01_成本/產能變動或資本支出
# 1426       M_經營層             MC01_勞資議題
# 1995      I_產業前景     IP01_成本/產能變動或資本支出
# 2080      I_產業前景        IR02_研發進程/技術合作
# 2110      I_產業前景     IP01_成本/產能變動或資本支出
# 2366      I_產業前景     IP01_成本/產能變動或資本支出
# 2432      I_產業前景     IP01_成本/產能變動或資本支出
# 2582      I_產業前景     IP01_成本/產能變動或資本支出
# 3012      I_產業前景     IP01_成本/產能變動或資本支出
# 3062      I_產業前景     IP01_成本/產能變動或資本支出
# 3167      I_產業前景     IP01_成本/產能變動或資本支出
# 3329       M_經營層             MT06_高管異動
# 3449      I_產業前景     IP01_成本/產能變動或資本支出
# 3538       M_經營層             MC03_工安議題
# 3643      I_產業前景     IP01_成本/產能變動或資本支出
# 3733      I_產業前景     IP01_成本/產能變動或資本支出
# 3802      I_產業前景          IR01_專利取得/侵權
# 4154      I_產業前景     IP01_成本/產能變動或資本支出
# 4214      I_產業前景     IP01_成本/產能變動或資本支出
# 4633      I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 5046      I_產業前景     IP01_成本/產能變動或資本支出
# 5172   A_會計/財報分析         AI04_自結數有重大差異
# 5173      I_產業前景     IP01_成本/產能變動或資本支出
# 5174      I_產業前景        IR02_研發進程/技術合作
# ...          ...                   ...
# 17158     I_產業前景     IP01_成本/產能變動或資本支出
# 17328     I_產業前景     IP01_成本/產能變動或資本支出
# 17329     I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 18062     I_產業前景     IP01_成本/產能變動或資本支出
# 18233     I_產業前景     IP01_成本/產能變動或資本支出
# 18290     I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 18409     I_產業前景     IP01_成本/產能變動或資本支出
# 18469     I_產業前景     IP01_成本/產能變動或資本支出
# 18535     I_產業前景     IP01_成本/產能變動或資本支出
# 18536     I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 18633     I_產業前景     IP01_成本/產能變動或資本支出
# 18692     I_產業前景     IP01_成本/產能變動或資本支出
# 18741     I_產業前景          IR01_專利取得/侵權
# 18742     I_產業前景          IR01_專利取得/侵權
# 18809      M_經營層             MC02_環保議題
# 18863     I_產業前景     IP01_成本/產能變動或資本支出
# 18932     I_產業前景        IR02_研發進程/技術合作
# 19017     I_產業前景     IP01_成本/產能變動或資本支出
# 19087     I_產業前景     IP01_成本/產能變動或資本支出
# 19188     I_產業前景     IP01_成本/產能變動或資本支出
# 19592     I_產業前景     IP01_成本/產能變動或資本支出
# 19593     I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 20158     I_產業前景     IP01_成本/產能變動或資本支出
# 20334     I_產業前景     IP01_成本/產能變動或資本支出
# 20436      M_經營層             MT06_高管異動
# 21506     I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 21781     I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 22588     I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 23299     I_產業前景  IS01_營收變動或客戶/商品/通路策略
# 23596     I_產業前景  IS01_營收變動或客戶/商品/通路策略
#
#                                                     事件內容
# 8                                   辭任1董。獨立董事湯馬斯?延吉布斯卸任。
# 825                            台積電以3,578 佰萬訂購機器設備，供生產用。。
# 927    2018年業績寫下新高的晶圓代工龍頭台積電，對於2019年首季展望轉趨悲觀，預估營收季減幅度...
# 1122   台積電澄清媒體報導，說明如下：。台積公司發現有一批化學原料有些規格誤差的問題會對良率產生影響...
# 1167   1.台積電在1月19日發現F14B的12及16奈米的良率出現問題，經追查後了解問題出在一批光...
# 1299   台積電以NT$2,739 佰萬元向(1) Applied Materials South E...
# 1357                  台積電以5,474 佰萬元購得機器及廠務設備乙批，供生產及營運用。。
# 1426   台積電（2330）12廠江姓助理工程師未遵照公司規則，逕行將新品下機報廢，總數多達46次，讓...
# 1995                  台積電以NT$1,145 佰萬元訂購廠務設備乙批，供生產及營運用。。
# 2080   半導體微影技術（lithography）終於迎來全新世代交替，過去10年主導半導體關鍵製程的...
# 2110     台積電以1,177 佰萬元向Tokyo Electron Ltd取得機器設備乙批，供生產用。。
# 2366    台積電以NT$1,152 佰萬元向KLA-Tencor Corp.取得機器設備一批，供生產用。。
# 2432         台積電為供生產及營運用，以$1,033 佰萬元向美超微電腦股份有限公司訂購廠務設備。。
# 2582   台積電以NT$2,804 佰萬元向Applied Materials South East ...
# 3012   台積電以7,943 佰萬元向新加坡商應用材料股份有限公司台灣分公司、香港商艾司摩爾貿易有限公...
# 3062      台積電以$1,008 佰萬元向香港商科林科技有限公司台灣分公司訂購機器設備乙批，供生產用。。
# 3167   台積電向Teradyne Asia Pte. Ltd.訂購機器設備以供生產用，交易總金額為1...
# 3329   台積電南科14B廠發生光阻劑汙染晶圓事件後，進行部分高層人事異動，原14B廠廠長張澐平行調至...
# 3449      台積電以1,001 佰萬元向日商村田機械株式會社台灣工程事務所訂購機器設備一批，供生產用。。
# 3538   台積電南科晶圓18廠上午傳出有廠房施工人員墜樓身亡，台積電表示，目前正調查事故原因，工程暫時...
# 3643       台積電以NT$889 佰萬元向泛亞工程建設股份有限公司取得工程設施一批，供生產及營運用。。
# 3733   台積電以NT$1,067 佰萬元向Applied Materials South East ...
# 3802   美國國際貿易委員會（ITC）投票決議，基於美國半導體及封裝公司Innovative Foun...
# 4154          台積電向帆宣系統科技股份有限公司以1,005 佰萬元訂購廠務一批，供生產及營運用。。
# 4214   台積電向Teradyne Asia Pte. Ltd.訂購機器設備一批以供生產用，交易總金額...
# 4633   2019年03月累計營收218,704,469千元，年減12%。2019年03月單月營收79...
# 5046     台積電以NT$1,009 佰萬元向Daifuku Co., Ltd.訂購機器一批，供生產用。。
# 5172   台積電公告2018年度海外財務報告因適用兩地會計原則不一致之差異，調節內容如下：。1.本國上...
# 5173       台積電以1,389 佰萬元向KLA-Tencor Corp.訂購機器設備一批，供生產用。。
# 5174   三星電子(Samsung Electronics)全面釋出7、6、5奈米製程進度，台積電也罕...
# ...                                                  ...
# 17158  台積電為供生產使用，向香港商艾司摩爾貿易有限公司台灣分公司，訂購機器設備一批，交易總金額新台...
# 17328  台積電為供生產使用，向Applied Materials South East Asia P...
# 17329  台積電宣布，領先業界導入極紫外光(EUV)微影技術的7奈米強效版(N7+)製程已協助客戶產品...
# 18062  台積電為供生產使用，向台灣迪恩士半導體科技股份有限公司購入新台幣10億元與Tokyo Ele...
# 18233  台積電為供生產用，向Daifuku Co., Ltd.、Applied Materials ...
# 18290  台積電召開法說會，第 3 季營收達 94 億美元，季增 21.3%，年增 10.7%；稅後純...
# 18409  台積電為供生產用，向Applied Materials South East Asia Pt...
# 18469  台積電為供生產及營運用，向漢唐集成股份有限公司、Lam Research Internati...
# 18535  台積電為供生產用，向Nanometrics Incorporated訂購機器設備一批，交易總...
# 18536  台積電5奈米接單再傳捷報，蘋果針對明年iPhone 12系列打造的全新A14應用處理器，採用...
# 18633  台積電為供生產用，向DAS Environmental Expert GmbH訂購機器設備一...
# 18692  台積電為供生產用，向Applied Materials South East Asia Pt...
# 18741  台積電 (29) 日宣布，與格芯 (GlobalFoundries) 共同撤銷雙方間、及與其...
# 18742  台積電 (29) 日宣布，與格芯 (GlobalFoundries) 共同撤銷雙方間、及與其...
# 18809  台積電在環評會議中公開表示，為了達到政府要求採用20%綠電的目標，正與屏東縣政府洽談合作，希...
# 18863  台積電為供生產用，向香港商艾司摩爾貿易有限公司台灣分公司訂購機器設備一批，交易總金額新台幣2...
# 18932  台積電將於竹科新建研發中心，打造成台灣的貝爾實驗室，預計再擴增8,000名研發大軍，投入未來...
# 19017  台積電代子公司台積電(南京)有限公司公告，為供生產用，向阿斯麥(上海)機電設備有限公司訂購機...
# 19087  台積電為供生產用，向ASM Japan KK與Applied Materials South...
# 19188  台積電為供生產用，向Tokyo Electron Ltd.與Nova Measuring I...
# 19592  台積電為供生產用，向Applied Materials South East Asia Pt...
# 19593  聯發科與台積電宣布採用台積電12奈米製程技術的聯發科8K數位電視系統單晶片S900進入量產，...
# 20158  台積電苗栗竹南先進封測建廠計畫，將投資 3000 億元，位於竹南科周邊特定區、大埔範圍，基地...
# 20334  行政院長蘇貞昌上周拍版南科擴建三期預定地落腳台南，台南經發局 (12) 日指出，台積電 5 ...
# 20436                               會計主管何麗梅內部調動，由翁銘莉接任。。
# 21506  高通(Qualcomm)推出3款旗艦手機5G晶片(驍龍865/765/765G)，預計在20...
# 21781  索尼(Sony)產能不足，旗下高階CIS首度釋單台積電，將於台積電南科14a廠導入40奈米製...
# 22588  光程研創 (Artilux) 宣布，將在2020年美國消費性電子展(CES)中，展出Expl...
# 23299  索尼(Sony)礙於產能不足，決定將旗下高階CIS首度釋單台積電，雙方已預定2020年1月正...
# 23596  蘋果A14採用5奈米製程，高通X55採用7奈米製程，晶圓代工訂單由台積電通吃，蘋果已包下台積...
#
# [164 rows x 11 columns]

# %%
TSMC.groupby('事件強度')['Season'].value_counts().unstack().plot.bar(stacked=True)
plt.title("台積電事件強度_堆疊長條圖")
plt.xlabel("事件強度")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
TSMC.groupby('Month')['大事件類別'].value_counts().unstack().plot.bar(stacked=True)
plt.title("台積電每季事件強度_堆疊長條圖")
plt.xlabel("月份")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
company = df.公司簡稱.value_counts()
print(len(company))
for i in range(0,len(company)):
    if company[i]==1:
        print(i)
        break
# Out:
# 1959
# 1903

# %%
a=str(company[1903:1959])
companysmall=a.split("1\n")
for i in range(0,len(companysmall)):
    companysmall[i]=companysmall[i].rstrip()
companysmall
# Out:
# ['加百裕',
#  '東明-KY',
#  '國碳科',
#  '久正',
#  '意德士',
#  '鉅祥',
#  '鑫永銓',
#  '鎰勝',
#  '越峰',
#  '皇田',
#  '新洲',
#  '圓剛',
#  '精聯',
#  '普誠',
#  '松和',
#  '湧盛',
#  '明輝-DR',
#  '亨泰光',
#  '寶一',
#  '立衛',
#  '逸昌',
#  '同方友友-DR',
#  '神州-DR',
#  '國眾',
#  '保綠-KY',
#  '利勤',
#  '康師傅-DR',
#  '通嘉',
#  '聖馬丁-DR',
#  '良得電',
#  '冠亞',
#  '安心',
#  '亞力',
#  '中菲',
#  '茂順',
#  '第一店',
#  '天仁',
#  '連鋐科技',
#  '宜新實業',
#  '大甲',
#  '佑華',
#  '創源',
#  '地球',
#  '青鋼',
#  '育富',
#  '台燿',
#  '超豐',
#  '群翊',
#  '運錩',
#  '勁豐',
#  '立誠',
#  '雙邦',
#  '廣宇',
#  '松翰',
#  '歐格',
#  '志豐',
#  'Name: 公司簡稱, dtype: int64']

# %% [markdown]
# 大事件類別

# %%
df.groupby('大事件類別')['事件強度'].value_counts().unstack().plot.bar(stacked=True)
plt.title("大事件類別與事件強度_堆疊長條圖")
plt.xlabel("大事件類別")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
positive.groupby('事件強度')['大事件類別'].value_counts()
# Out:
# 事件強度  大事件類別
# 1     I_產業前景       3478
#       F_市場交易         18
#       M_經營層           9
#       A_會計/財報分析       2
# 2     F_市場交易         53
#       I_產業前景         41
# 3     F_市場交易         71
#       I_產業前景          2
# Name: 大事件類別, dtype: int64

# %%
positive.groupby('事件強度')['大事件類別'].value_counts().unstack().plot.bar(stacked=True)
plt.title("大事件類別與事件強度(正)_堆疊長條圖")
plt.xlabel("大事件類別")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
negative.groupby('事件強度')['大事件類別'].value_counts()
# Out:
# 事件強度  大事件類別
# -3    R_危機          170
#       A_會計/財報分析      10
#       I_產業前景         10
#       M_經營層           3
# -2    R_危機          247
#       I_產業前景        137
#       A_會計/財報分析      96
#       M_經營層          64
#       F_市場交易          4
# -1    I_產業前景       6241
#       M_經營層        2817
#       F_市場交易        864
#       A_會計/財報分析     234
#  0    I_產業前景       4927
#       M_經營層        3065
#       A_會計/財報分析     118
#       F_市場交易         91
#       R_危機            3
# Name: 大事件類別, dtype: int64

# %%
negative.groupby('事件強度')['大事件類別'].value_counts().unstack().plot.bar(stacked=True)
plt.title("大事件類別與事件強度(負)_堆疊長條圖")
plt.xlabel("大事件類別")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %% [markdown]
# TCRI

# %%
df.groupby('TCRI')['強度分類'].value_counts().unstack().plot.bar(stacked=True)
plt.title("TCRI與強度分類_堆疊長條圖")
plt.xlabel("TCRI")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
positive.groupby('TCRI')['事件強度'].value_counts().unstack().plot.bar(stacked=True)
plt.title("TCRI事件強度_堆疊長條圖")
plt.xlabel("TCRI")
plt.ylabel("件數")
# Out:
# Text(0, 0.5, '件數')

# %%
import jieba
import jieba.analyse
import os
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib.font_manager import FontProperties
from wordcloud import WordCloud
myfont = FontProperties(fname=os.path.join('D:/Anaconda/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/msj.ttf'))

# %%
def cut(text):
    tags = jieba.analyse.extract_tags(text)
    tags = " ".join(tags)
    return tags
old=str(" ")
for i in range(0,len(df)): 
    new=cut(df.iloc[i,7])
    old=old+str(new)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.cache
# Loading model cost 0.754 seconds.
# Prefix dict has been built succesfully.

# %%
my_wordcloud = WordCloud(background_color='white',font_path='D:/Anaconda/Lib/site-packages/matplotlib/mpl-data/fonts/ttf/msj.ttf').generate(old)
plt.imshow(my_wordcloud)
plt.axis('on')
plt.show()
